# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** Connie Francis
#
# **Turma:** 2ºA TI
#
# **Tema Escolhido:**  Um sistema que catalogue filmes assistidos, cadastrando nome,
# gênero e duração, permitindo filtrar filmes por gênero e marcar como
# assistido.

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
# Definição da classe principal com nome personalizado
class Filme_Connie:
    def __init__Connie(self, nome, genero, duracao):
        self.nome = nome
        self.genero = genero
        self.duracao = duracao  # duração em minutos
        self.assistido = False  # padrão: ainda não assistido

    # Método para exibir os dados do filme
    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        print(f"Nome: {self.nome}")
        print(f"Gênero: {self.genero}")
        print(f"Duração: {self.duracao} minutos")
        print(f"Status: {status}")
        print("-" * 30)

    # Método para marcar o filme como assistido
    def marcar_como_assistido_Connie(self):
        self.assistido = True


# Criação de objetos (filmes)
filme1_Connie = Filme_Connie()
filme1_Connie.__init__Connie("A Origem", "Ficção Científica", 148)

filme2_Connie = Filme_Connie()
filme2_Connie.__init__Connie("O Poderoso Chefão", "Drama", 175)

# Exibição dos dados dos filmes
filme1_Connie.exibir_dados_Connie()
filme2_Connie.exibir_dados_Connie()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
# Classe principal
class Filme_Connie:
    def __init__Connie(self, nome, genero, duracao):
        self.nome = nome
        self.genero = genero
        self.duracao = duracao
        self.assistido = False

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        print(f"Nome: {self.nome}")
        print(f"Gênero: {self.genero}")
        print(f"Duração: {self.duracao} minutos")
        print(f"Status: {status}")
        print("-" * 30)

    def marcar_como_assistido_Connie(self):
        self.assistido = True

    @staticmethod
    def filtrar_por_genero_Connie(genero, lista_filmes):
        print(f"Filmes do gênero '{genero}':")
        for filme in lista_filmes:
            if filme.genero.lower() == genero.lower():
                print(f"- {filme.nome}")
        print("-" * 30)


# Subclasse herdando de Filme_Connie
class FilmeFavorito_Connie(Filme_Connie):
    def __init__Connie(self, nome, genero, duracao, nota):
        super().__init__Connie(nome, genero, duracao)
        self.nota = nota

    def avaliar_filme_Connie(self, nova_nota):
        if 0 <= nova_nota <= 10:
            self.nota = nova_nota
        else:
            print("A nota deve estar entre 0 e 10.")

    def exibir_dados_Connie(self):
        super().exibir_dados_Connie()
        print(f"Nota: {self.nota}/10")
        print("-" * 30)


# Criando objetos
filme1_Connie = Filme_Connie()
filme1_Connie.__init__Connie("A Origem", "Ficção Científica", 148)

filme2_Connie = Filme_Connie()
filme2_Connie.__init__Connie("O Poderoso Chefão", "Drama", 175)

filme3_Connie = FilmeFavorito_Connie()
filme3_Connie.__init__Connie("Interestelar", "Ficção Científica", 169, 9)

# Marcando um filme como assistido
filme1_Connie.marcar_como_assistido_Connie()

# Exibindo dados
filme1_Connie.exibir_dados_Connie()
filme2_Connie.exibir_dados_Connie()
filme3_Connie.exibir_dados_Connie()

# Avaliando filme favorito
filme3_Connie.avaliar_filme_Connie(10)

# Usando método de filtragem
Filme_Connie.filtrar_por_genero_Connie("Ficção Científica", [filme1_Connie, filme2_Connie, filme3_Connie])

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
# Classe principal com encapsulamento, abstração e sufixo _Connie
class Filme_Connie:
    def __init__Connie(self, nome, genero, duracao):
        self.nome = nome
        self.genero = genero
        self.__duracao = duracao  # Atributo privado
        self.assistido = False

    # Getter para duração
    def get_duracao_Connie(self):
        return self.__duracao

    # Setter para duração com verificação
    def set_duracao_Connie(self, nova_duracao):
        if nova_duracao > 0:
            self.__duracao = nova_duracao
        else:
            print("A duração deve ser positiva.")

    # Método de lógica interna (abstração)
    def classificar_duracao_Connie(self):
        if self.__duracao < 90:
            return "Curto"
        elif 90 <= self.__duracao <= 150:
            return "Médio"
        else:
            return "Longo"

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        print(f"Nome: {self.nome}")
        print(f"Gênero: {self.genero}")
        print(f"Duração: {self.__duracao} minutos ({self.classificar_duracao_Connie()})")
        print(f"Status: {status}")
        print("-" * 30)

    def marcar_como_assistido_Connie(self):
        self.assistido = True

    @staticmethod
    def filtrar_por_genero_Connie(genero, lista_filmes):
        print(f"Filmes do gênero '{genero}':")
        for filme in lista_filmes:
            if filme.genero.lower() == genero.lower():
                print(f"- {filme.nome}")
        print("-" * 30)


# Subclasse com herança e sufixo _Connie
class FilmeFavorito_Connie(Filme_Connie):
    def __init__Connie(self, nome, genero, duracao, nota):
        super().__init__Connie(nome, genero, duracao)
        self.nota = nota

    def avaliar_filme_Connie(self, nova_nota):
        if 0 <= nova_nota <= 10:
            self.nota = nova_nota
        else:
            print("A nota deve estar entre 0 e 10.")

    def exibir_dados_Connie(self):
        super().exibir_dados_Connie()
        print(f"Nota: {self.nota}/10")
        print("-" * 30)


# Testando o sistema com sufixo _Connie

filme1_Connie = Filme_Connie()
filme1_Connie.__init__Connie("A Origem", "Ficção Científica", 148)

filme2_Connie = Filme_Connie()
filme2_Connie.__init__Connie("Curtindo a Vida Adoidado", "Comédia", 103)

filme3_Connie = FilmeFavorito_Connie()
filme3_Connie.__init__Connie("Interestelar", "Ficção Científica", 169, 9)

# Marcando como assistido
filme1_Connie.marcar_como_assistido_Connie()

# Avaliando filme favorito
filme3_Connie.avaliar_filme_Connie(10)

# Exibindo dados
filme1_Connie.exibir_dados_Connie()
filme2_Connie.exibir_dados_Connie()
filme3_Connie.exibir_dados_Connie()

# Testando setter e getter
filme2_Connie.set_duracao_Connie(85)
print(f"Nova duração de {filme2_Connie.nome}: {filme2_Connie.get_duracao_Connie()} minutos")

# Usando filtro por gênero
Filme_Connie.filtrar_por_genero_Connie("Ficção Científica", [filme1_Connie, filme2_Connie, filme3_Connie])

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4
import sqlite3

# ----- CLASSES -----
class Filme_Connie:
    def __init__Connie(self, nome, genero, duracao):
        self.nome = nome
        self.genero = genero
        self.__duracao = duracao
        self.assistido = False

    def get_duracao_Connie(self):
        return self.__duracao

    def set_duracao_Connie(self, nova_duracao):
        if nova_duracao > 0:
            self.__duracao = nova_duracao

    def classificar_duracao_Connie(self):
        if self.__duracao < 90:
            return "Curto"
        elif 90 <= self.__duracao <= 150:
            return "Médio"
        else:
            return "Longo"

    def marcar_como_assistido_Connie(self):
        self.assistido = True

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        print(f"[Filme] Nome: {self.nome}")
        print(f"Gênero: {self.genero}")
        print(f"Duração: {self.__duracao} minutos ({self.classificar_duracao_Connie()})")
        print(f"Status: {status}")
        print("-" * 30)


class FilmeFavorito_Connie(Filme_Connie):
    def __init__Connie(self, nome, genero, duracao, nota):
        super().__init__Connie(nome, genero, duracao)
        self.nota = nota

    def avaliar_filme_Connie(self, nova_nota):
        if 0 <= nova_nota <= 10:
            self.nota = nova_nota

    def exibir_dados_Connie(self):
        super().exibir_dados_Connie()
        print(f"Nota: {self.nota}/10")
        print("-" * 30)


# ----- BANCO DE DADOS -----
def conectar_banco_Connie():
    return sqlite3.connect("catalogo_filmes.db")

def criar_tabela_Connie():
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS filmes (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            nome TEXT NOT NULL,
            genero TEXT NOT NULL,
            duracao INTEGER NOT NULL,
            assistido INTEGER NOT NULL,
            nota REAL
        )
    """)
    conn.commit()
    conn.close()

def inserir_filme_Connie(filme):
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    assistido = 1 if filme.assistido else 0
    nota = getattr(filme, 'nota', None)
    cursor.execute("""
        INSERT INTO filmes (nome, genero, duracao, assistido, nota)
        VALUES (?, ?, ?, ?, ?)
    """, (filme.nome, filme.genero, filme.get_duracao_Connie(), assistido, nota))
    conn.commit()
    conn.close()
    print(f"Filme '{filme.nome}' inserido no banco de dados.")

def consultar_filmes_Connie():
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    cursor.execute("SELECT id, nome, genero, duracao, assistido, nota FROM filmes")
    filmes = cursor.fetchall()
    conn.close()
    print("🎬 Filmes no banco de dados:")
    for f in filmes:
        status = "Assistido" if f[4] else "Não assistido"
        nota_str = f"{f[5]}/10" if f[5] is not None else "Sem nota"
        print(f"ID: {f[0]} | Nome: {f[1]} | Gênero: {f[2]} | Duração: {f[3]} min | {status} | Nota: {nota_str}")
    print("-" * 50)

def excluir_filme_Connie(filme_id):
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    cursor.execute("DELETE FROM filmes WHERE id = ?", (filme_id,))
    conn.commit()
    conn.close()
    print(f"Filme com ID {filme_id} foi excluído.")


# ----- TESTANDO TUDO -----
if __name__ == "__main__":
    criar_tabela_Connie()

    # Criando objetos
    filme1_Connie = Filme_Connie()
    filme1_Connie.__init__Connie("Matrix", "Ficção Científica", 136)
    filme1_Connie.marcar_como_assistido_Connie()

    filme2_Connie = FilmeFavorito_Connie()
    filme2_Connie.__init__Connie("Gladiador", "Ação", 155, 9)
    filme2_Connie.marcar_como_assistido_Connie()

    # Inserindo no banco
    inserir_filme_Connie(filme1_Connie)
    inserir_filme_Connie(filme2_Connie)

    # Consultando dados
    consultar_filmes_Connie()

    # Exibindo via métodos de classe (com polimorfismo)
    print("\n📺 Exibição individual com métodos:")
    filme1_Connie.exibir_dados_Connie()
    filme2_Connie.exibir_dados_Connie()

    # Excluindo um filme (exemplo: ID 1)
    # excluir_filme_Connie(1)

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5
import sqlite3

# -----------------------------
# CLASSE PRINCIPAL: Filme_Connie
# -----------------------------
class Filme_Connie:
    def __init__Connie(self, nome, genero, duracao):
        self.nome = nome
        self.genero = genero
        self.__duracao = duracao  # atributo privado
        self.assistido = False

    # Encapsulamento: métodos get/set
    def get_duracao_Connie(self):
        return self.__duracao

    def set_duracao_Connie(self, nova_duracao):
        if nova_duracao > 0:
            self.__duracao = nova_duracao
        else:
            print("Duração inválida.")

    # Abstração: lógica interna para classificar o tipo de filme
    def classificar_duracao_Connie(self):
        if self.__duracao < 90:
            return "Curto"
        elif 90 <= self.__duracao <= 150:
            return "Médio"
        else:
            return "Longo"

    def marcar_como_assistido_Connie(self):
        self.assistido = True

    # Método que pode ser sobrescrito (Polimorfismo)
    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        print(f"[Filme] Nome: {self.nome}")
        print(f"Gênero: {self.genero}")
        print(f"Duração: {self.__duracao} minutos ({self.classificar_duracao_Connie()})")
        print(f"Status: {status}")
        print("-" * 30)

# -----------------------------
# SUBCLASSE: FilmeFavorito_Connie
# -----------------------------
class FilmeFavorito_Connie(Filme_Connie):
    def __init__Connie(self, nome, genero, duracao, nota):
        super().__init__Connie(nome, genero, duracao)
        self.nota = nota

    def avaliar_filme_Connie(self, nova_nota):
        if 0 <= nova_nota <= 10:
            self.nota = nova_nota
        else:
            print("Nota deve estar entre 0 e 10.")

    # Polimorfismo: sobrescrevendo método da classe pai
    def exibir_dados_Connie(self):
        super().exibir_dados_Connie()
        print(f"Nota: {self.nota}/10")
        print("-" * 30)

# -----------------------------
# BANCO DE DADOS – SQLite
# -----------------------------
def conectar_banco_Connie():
    return sqlite3.connect("catalogo_filmes.db")

def criar_tabela_Connie():
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS filmes (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            nome TEXT NOT NULL,
            genero TEXT NOT NULL,
            duracao INTEGER NOT NULL,
            assistido INTEGER NOT NULL,
            nota REAL
        )
    """)
    conn.commit()
    conn.close()

def inserir_filme_Connie(filme):
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    assistido = 1 if filme.assistido else 0
    nota = getattr(filme, 'nota', None)
    cursor.execute("""
        INSERT INTO filmes (nome, genero, duracao, assistido, nota)
        VALUES (?, ?, ?, ?, ?)
    """, (filme.nome, filme.genero, filme.get_duracao_Connie(), assistido, nota))
    conn.commit()
    conn.close()
    print(f"Filme '{filme.nome}' inserido com sucesso.")

def consultar_filmes_Connie():
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    cursor.execute("SELECT id, nome, genero, duracao, assistido, nota FROM filmes")
    filmes = cursor.fetchall()
    conn.close()

    print("\n🎬 Filmes cadastrados:")
    for f in filmes:
        status = "Assistido" if f[4] else "Não assistido"
        nota_str = f"{f[5]}/10" if f[5] is not None else "Sem nota"
        print(f"ID: {f[0]} | Nome: {f[1]} | Gênero: {f[2]} | Duração: {f[3]} min | {status} | Nota: {nota_str}")
    print("-" * 50)

def excluir_filme_Connie(filme_id):
    conn = conectar_banco_Connie()
    cursor = conn.cursor()
    cursor.execute("DELETE FROM filmes WHERE id = ?", (filme_id,))
    conn.commit()
    conn.close()
    print(f"Filme com ID {filme_id} excluído.")

# -----------------------------
# TESTANDO O SISTEMA COMPLETO
# -----------------------------
if __name__ == "__main__":
    criar_tabela_Connie()

    # Criando objetos
    filme1_Connie = Filme_Connie()
    filme1_Connie.__init__Connie("Matrix", "Ficção Científica", 136)
    filme1_Connie.marcar_como_assistido_Connie()

    filme2_Connie = FilmeFavorito_Connie()
    filme2_Connie.__init__Connie("Gladiador", "Ação", 155, 9)
    filme2_Connie.marcar_como_assistido_Connie()

    filme3_Connie = Filme_Connie()
    filme3_Connie.__init__Connie("Toy Story", "Animação", 81)

    # Inserindo no banco
    inserir_filme_Connie(filme1_Connie)
    inserir_filme_Connie(filme2_Connie)
    inserir_filme_Connie(filme3_Connie)

    # Consulta e exibição
    consultar_filmes_Connie()

    print("\n📺 Exibição individual com métodos:")
    filme1_Connie.exibir_dados_Connie()
    filme2_Connie.exibir_dados_Connie()
    filme3_Connie.exibir_dados_Connie()

    # Exclusão de filme por ID (exemplo: id 2)
    # excluir_filme_Connie(2)
