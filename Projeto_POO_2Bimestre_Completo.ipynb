# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** Connie Francis
#
# **Turma:** 2ºA TI
#
# **Tema Escolhido:**  Um sistema que catalogue filmes assistidos, cadastrando nome,
# gênero e duração, permitindo filtrar filmes por gênero e marcar como
# assistido.

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
class Filme_Connie:
    def __init__(self, nome, genero, duracao):
        self.nome = nome
        self.genero = genero
        self.duracao = duracao
        self.assistido = False  # A princípio, o filme não é assistido

    def marcar_como_assistido_Connie(self):
        self.assistido = True
        return f'O filme "{self.nome}" foi marcado como assistido.'

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        return f'Filme: {self.nome}, Gênero: {self.genero}, Duração: {self.duracao} minutos, Status: {status}'

    def filtrar_por_genero_Connie(self, genero):
        if self.genero.lower() == genero.lower():
            return f'O filme "{self.nome}" pertence ao gênero "{self.genero}".'
        else:
            return f'O filme "{self.nome}" não pertence ao gênero "{genero}".'

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
class Filme_Connie:
    def __init__(self, nome, genero, duracao):
        self.nome = nome
        self.genero = genero
        self.duracao = duracao
        self.assistido = False  # A princípio, o filme não é assistido

    def marcar_como_assistido_Connie(self):
        self.assistido = True
        return f'O filme "{self.nome}" foi marcado como assistido.'

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        return f'Filme: {self.nome}, Gênero: {self.genero}, Duração: {self.duracao} minutos, Status: {status}'

    def filtrar_por_genero_Connie(self, genero):
        if self.genero.lower() == genero.lower():
            return f'O filme "{self.nome}" pertence ao gênero "{self.genero}".'
        else:
            return f'O filme "{self.nome}" não pertence ao gênero "{genero}".'

    # Método 1: Alterar o gênero do filme
    def alterar_genero_Connie(self, novo_genero):
        self.genero = novo_genero
        return f'O gênero do filme "{self.nome}" foi alterado para "{self.genero}".'

    # Método 2: Alterar a duração do filme
    def alterar_duracao_Connie(self, nova_duracao):
        self.duracao = nova_duracao
        return f'A duração do filme "{self.nome}" foi alterada para {self.duracao} minutos.'

# Subclasse - Filme_Serie_Connie
class Filme_Serie_Connie(Filme_Connie):
    def __init__(self, nome, genero, duracao, temporadas):
        super().__init__(nome, genero, duracao)
        self.temporadas = temporadas  # Novo atributo exclusivo da subclasse

    # Novo método exclusivo da subclasse
    def exibir_temporadas_Connie(self):
        return f'A série "{self.nome}" possui {self.temporadas} temporadas.'

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class Filme_Connie:
    def __init__(self, nome, genero, duracao):
        self.__nome = nome  # Atributo privado
        self.genero = genero
        self.duracao = duracao
        self.assistido = False  # A princípio, o filme não é assistido

    # Método 'get' para o atributo privado __nome
    def get_nome_Connie(self):
        return self.__nome

    # Método 'set' para o atributo privado __nome
    def set_nome_Connie(self, novo_nome):
        if isinstance(novo_nome, str) and len(novo_nome) > 0:
            self.__nome = novo_nome
            return f'O nome do filme foi alterado para "{self.__nome}".'
        else:
            return 'Nome inválido. O nome deve ser uma string não vazia.'

    def marcar_como_assistido_Connie(self):
        self.assistido = True
        return f'O filme "{self.__nome}" foi marcado como assistido.'

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        return f'Filme: {self.__nome}, Gênero: {self.genero}, Duração: {self.duracao} minutos, Status: {status}'

    def filtrar_por_genero_Connie(self, genero):
        if self.genero.lower() == genero.lower():
            return f'O filme "{self.__nome}" pertence ao gênero "{self.genero}".'
        else:
            return f'O filme "{self.__nome}" não pertence ao gênero "{genero}".'

    # Método 1: Alterar o gênero do filme
    def alterar_genero_Connie(self, novo_genero):
        self.genero = novo_genero
        return f'O gênero do filme "{self.__nome}" foi alterado para "{self.genero}".'

    # Método 2: Alterar a duração do filme
    def alterar_duracao_Connie(self, nova_duracao):
        self.duracao = nova_duracao
        return f'A duração do filme "{self.__nome}" foi alterada para {self.duracao} minutos.'

    # Método de lógica interna: Verificar se o filme é longo ou curto
    def verificar_duracao_Connie(self):
        if self.duracao > 120:
            return f'O filme "{self.__nome}" é considerado longo.'
        else:
            return f'O filme "{self.__nome}" é considerado curto.'

# Subclasse - Filme_Serie_Connie
class Filme_Serie_Connie(Filme_Connie):
    def __init__(self, nome, genero, duracao, temporadas):
        super().__init__(nome, genero, duracao)
        self.temporadas = temporadas  # Novo atributo exclusivo da subclasse

    # Novo método exclusivo da subclasse
    def exibir_temporadas_Connie(self):
        return f'A série "{self.get_nome_Connie()}" possui {self.temporadas} temporadas.'

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4
import sqlite3

# Classe principal Filme_Connie
class Filme_Connie:
    def __init__(self, nome, genero, duracao):
        self.__nome = nome  # Atributo privado
        self.genero = genero
        self.duracao = duracao
        self.assistido = False  # A princípio, o filme não é assistido

    # Métodos 'get' e 'set' para o nome
    def get_nome_Connie(self):
        return self.__nome

    def set_nome_Connie(self, novo_nome):
        if isinstance(novo_nome, str) and len(novo_nome) > 0:
            self.__nome = novo_nome
            return f'O nome do filme foi alterado para "{self.__nome}".'
        else:
            return 'Nome inválido. O nome deve ser uma string não vazia.'

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        return f'Filme: {self.__nome}, Gênero: {self.genero}, Duração: {self.duracao} minutos, Status: {status}'

    # Polimorfismo: Sobrescrevendo este método na subclasse
    def detalhes_Connie(self):
        return f'Detalhes do filme: {self.__nome}, {self.genero}, {self.duracao} minutos.'

    def filtrar_por_genero_Connie(self, genero):
        if self.genero.lower() == genero.lower():
            return f'O filme "{self.__nome}" pertence ao gênero "{self.genero}".'
        else:
            return f'O filme "{self.__nome}" não pertence ao gênero "{genero}".'

# Subclasse Filme_Serie_Connie
class Filme_Serie_Connie(Filme_Connie):
    def __init__(self, nome, genero, duracao, temporadas):
        super().__init__(nome, genero, duracao)
        self.temporadas = temporadas  # Novo atributo exclusivo da subclasse

    # Sobrescrevendo o método detalhes_Connie para exibir detalhes de séries
    def detalhes_Connie(self):
        return f'Detalhes da série: {self.get_nome_Connie()}, {self.genero}, {self.duracao} minutos, {self.temporadas} temporadas.'

# Banco de Dados (SQLite)
class BancoDeDados:
    def __init__(self):
        self.conn = sqlite3.connect('filmes.db')
        self.cursor = self.conn.cursor()
        self.criar_tabela()

    def criar_tabela(self):
        # Criação da tabela de filmes (nome, gênero, duração)
        self.cursor.execute('''CREATE TABLE IF NOT EXISTS filmes (
                                id INTEGER PRIMARY KEY AUTOINCREMENT,
                                nome TEXT,
                                genero TEXT,
                                duracao INTEGER,
                                assistido BOOLEAN)''')
        self.conn.commit()

    def inserir_filme(self, filme):
        # Inserção de filme no banco de dados
        self.cursor.execute('''INSERT INTO filmes (nome, genero, duracao, assistido)
                               VALUES (?, ?, ?, ?)''', 
                               (filme.get_nome_Connie(), filme.genero, filme.duracao, filme.assistido))
        self.conn.commit()

    def consultar_filmes(self):
        # Consulta todos os filmes no banco de dados
        self.cursor.execute('SELECT * FROM filmes')
        return self.cursor.fetchall()

    def excluir_filme(self, filme_id):
        # Excluir um filme pelo id
        self.cursor.execute('DELETE FROM filmes WHERE id = ?', (filme_id,))
        self.conn.commit()

    def fechar_conexao(self):
        self.conn.close()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3

# Classe principal - Filme_Connie
class Filme_Connie:
    def __init__(self, nome, genero, duracao, assistido=False):
        self.__nome = nome
        self.genero = genero
        self.duracao = duracao
        self.assistido = assistido

    def get_nome_Connie(self):
        return self.__nome

    def set_nome_Connie(self, novo_nome):
        if isinstance(novo_nome, str) and len(novo_nome) > 0:
            self.__nome = novo_nome
            return f'O nome do filme foi alterado para "{self.__nome}".'
        else:
            return 'Nome inválido. O nome deve ser uma string não vazia.'

    def exibir_dados_Connie(self):
        status = "Assistido" if self.assistido else "Não assistido"
        return f'Filme: {self.__nome}, Gênero: {self.genero}, Duração: {self.duracao} minutos, Status: {status}'

    def detalhes_Connie(self):
        return f'Detalhes do filme: {self.__nome}, {self.genero}, {self.duracao} minutos.'

    def alterar_genero_Connie(self, novo_genero):
        self.genero = novo_genero
        return f'O gênero do filme "{self.__nome}" foi alterado para "{self.genero}".'

    def alterar_duracao_Connie(self, nova_duracao):
        self.duracao = nova_duracao
        return f'A duração do filme "{self.__nome}" foi alterada para {self.duracao} minutos.'

    def alterar_status_assistido(self, assistido):
        self.assistido = assistido
        status_texto = "Assistido" if assistido else "Não assistido"
        return f'Status do filme "{self.__nome}" alterado para "{status_texto}".'

    def verificar_duracao_Connie(self):
        if self.duracao > 120:
            return f'O filme "{self.__nome}" é considerado longo.'
        else:
            return f'O filme "{self.__nome}" é considerado curto.'


# Classe para gerenciamento do Banco de Dados
class BancoDeDados:
    def __init__(self):
        self.conn = sqlite3.connect('filmes.db')
        self.cursor = self.conn.cursor()
        self.criar_tabela()

    def criar_tabela(self):
        self.cursor.execute('''
            CREATE TABLE IF NOT EXISTS filmes (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                nome TEXT,
                genero TEXT,
                duracao INTEGER,
                assistido INTEGER
            )
        ''')
        self.conn.commit()

    def inserir_filme(self, filme):
        self.cursor.execute('''
            INSERT INTO filmes (nome, genero, duracao, assistido)
            VALUES (?, ?, ?, ?)
        ''', (filme.get_nome_Connie(), filme.genero, filme.duracao, int(filme.assistido)))
        self.conn.commit()

    def consultar_filmes(self):
        self.cursor.execute('SELECT * FROM filmes')
        return self.cursor.fetchall()

    def excluir_filme(self, filme_id):
        self.cursor.execute('DELETE FROM filmes WHERE id = ?', (filme_id,))
        self.conn.commit()

    def editar_filme(self, filme_id, novo_nome, novo_genero, nova_duracao, novo_assistido):
        print(f"[DEBUG] Atualizando filme ID {filme_id} com os valores: {novo_nome}, {novo_genero}, {nova_duracao}, {int(novo_assistido)}")
        self.cursor.execute('''
            UPDATE filmes
            SET nome = ?, genero = ?, duracao = ?, assistido = ?
            WHERE id = ?
        ''', (novo_nome, novo_genero, nova_duracao, int(novo_assistido), filme_id))
        self.conn.commit()

    def fechar_conexao(self):
        self.conn.close()


def input_assistido():
    while True:
        resposta = input("Já assistiu? (s/n): ").strip().lower()
        if resposta == 's':
            return True
        elif resposta == 'n':
            return False
        else:
            print("⚠️ Resposta inválida. Digite 's' para sim ou 'n' para não.")


# Função principal com menu de interação
def menu():
    db = BancoDeDados()

    while True:
        print("\n🎬 MENU DE FILMES")
        print("1 - Adicionar novo filme")
        print("2 - Visualizar todos os filmes")
        print("3 - Editar um filme")
        print("4 - Excluir um filme")
        print("5 - Sair")

        opcao = input("Escolha uma opção: ").strip()

        if opcao == "1":
            nome = input("Nome do filme: ").strip()
            genero = input("Gênero: ").strip()
            try:
                duracao = int(input("Duração (minutos): "))
                if duracao <= 0:
                    print("⚠️ A duração deve ser um número positivo.")
                    continue
            except ValueError:
                print("⚠️ Duração inválida. Digite um número inteiro.")
                continue
            assistido = input_assistido()
            filme = Filme_Connie(nome, genero, duracao, assistido)
            db.inserir_filme(filme)
            print("✅ Filme adicionado com sucesso!")

        elif opcao == "2":
            filmes = db.consultar_filmes()
            if filmes:
                print("\n📋 Lista de Filmes:")
                for f in filmes:
                    status = "Sim" if f[4] else "Não"
                    print(f"ID: {f[0]} | Nome: {f[1]} | Gênero: {f[2]} | Duração: {f[3]} min | Assistido: {status}")
            else:
                print("⚠️ Nenhum filme encontrado.")

        elif opcao == "3":
            try:
                id_filme = int(input("ID do filme que deseja editar: "))
            except ValueError:
                print("⚠️ ID inválido. Digite um número inteiro.")
                continue

            filmes = db.consultar_filmes()
            ids = [f[0] for f in filmes]
            if id_filme not in ids:
                print(f"⚠️ Filme com ID {id_filme} não encontrado.")
                continue

            novo_nome = input("Novo nome: ").strip()
            if not novo_nome:
                print("⚠️ Nome não pode estar vazio.")
                continue

            novo_genero = input("Novo gênero: ").strip()
            if not novo_genero:
                print("⚠️ Gênero não pode estar vazio.")
                continue

            try:
                nova_duracao = int(input("Nova duração (minutos): "))
                if nova_duracao <= 0:
                    print("⚠️ A duração deve ser um número positivo.")
                    continue
            except ValueError:
                print("⚠️ Duração inválida. Digite um número inteiro.")
                continue

            novo_assistido = input_assistido()

            db.editar_filme(id_filme, novo_nome, novo_genero, nova_duracao, novo_assistido)
            print("✏️ Filme atualizado com sucesso!")

            # Mostrar filme atualizado
            filmes = db.consultar_filmes()
            for f in filmes:
                if f[0] == id_filme:
                    status = "Sim" if f[4] else "Não"
                    print(f"🔄 Filme atualizado: ID: {f[0]} | Nome: {f[1]} | Gênero: {f[2]} | Duração: {f[3]} min | Assistido: {status}")

        elif opcao == "4":
            try:
                id_filme = int(input("ID do filme que deseja excluir: "))
            except ValueError:
                print("⚠️ ID inválido. Digite um número inteiro.")
                continue

            filmes = db.consultar_filmes()
            ids = [f[0] for f in filmes]
            if id_filme not in ids:
                print(f"⚠️ Filme com ID {id_filme} não encontrado.")
                continue

            db.excluir_filme(id_filme)
            print("🗑️ Filme excluído com sucesso!")

        elif opcao == "5":
            db.fechar_conexao()
            print("👋 Saindo do sistema...")
            break

        else:
            print("❌ Opção inválida. Tente novamente.")


if __name__ == "__main__":
    menu()
# Out:
# 🎬 MENU DE FILMES
# 1 - Adicionar novo filme
# 2 - Visualizar todos os filmes
# 3 - Editar um filme
# 4 - Excluir um filme
# 5 - Sair
#
# 📋 Lista de Filmes:
# ID: 1 | Nome: 2 | Gênero: 1 | Duração: 1 min | Assistido: Não
# ID: 2 | Nome: 2 | Gênero: 3 | Duração: 4 min | Assistido: Não
# ID: 3 | Nome: 1 | Gênero:  | Duração: 1 min | Assistido: Sim
# ID: 4 | Nome: Shrek | Gênero: Comédi | Duração: 120 min | Assistido: Sim
# ID: 5 | Nome: Lilo & Stitch | Gênero: Comédia | Duração: 100 min | Assistido: Sim
#
# 🎬 MENU DE FILMES
# 1 - Adicionar novo filme
# 2 - Visualizar todos os filmes
# 3 - Editar um filme
# 4 - Excluir um filme
# 5 - Sair
